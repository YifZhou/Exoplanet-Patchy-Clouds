# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
f125DF = pd.read_csv('f125aperphot.dat', sep = '\s+', names = ['obs-date', 'obs-time', 'flux'], parse_dates = True)
f160DF = pd.read_csv('f160aperphot.dat', sep = '\s+', names = ['obs-date', 'obs-time', 'flux'], parse_dates = True)

# %%
total = pd.concat([f125DF,f160DF], ignore_index = True)
total.sort(columns = ['obs-date', 'obs-time'])
total
# Out:
#       obs-date  obs-time     flux
# 0   2013-10-16  15:56:11  8187.81
# 1   2013-10-16  16:02:56  8165.36
# 2   2013-10-16  16:09:42  8177.46
# 3   2013-10-16  16:16:27  8194.76
# 4   2013-10-16  16:23:12  8168.25
# 5   2013-10-16  16:29:57  8192.28
# 6   2013-10-16  16:36:06  8209.04
# 7   2013-10-16  17:31:48  8163.31
# 8   2013-10-16  17:38:33  8176.46
# 9   2013-10-16  17:45:19  8057.22
# 10  2013-10-16  17:52:04  8137.89
# 11  2013-10-16  17:58:49  8047.05
# 12  2013-10-16  18:05:34  8098.15
# 13  2013-10-16  18:11:43  8149.23
# 14  2013-10-16  19:07:26  8274.52
# 15  2013-10-16  19:14:11  8164.92
# 16  2013-10-16  19:20:57  8154.19
# 17  2013-10-16  19:27:42  8167.66
# 18  2013-10-16  19:34:28  8239.25
# 19  2013-10-16  19:41:13  8195.00
# 20  2013-10-16  19:47:22  8179.74
# 21  2013-10-16  20:43:04  8151.04
# 22  2013-10-16  20:49:13  8167.94
# 23  2013-10-16  20:55:22  8184.65
# 24  2013-10-16  21:01:31  8173.93
# 25  2013-10-16  21:07:40  8172.13
# ...
